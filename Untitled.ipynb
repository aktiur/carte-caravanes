# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('produits.csv')

# %%
cars = df[df.Nom.str.startswith('Car') & (df['Publié'] == 1)]

# %%
cars['Stock'] = cars.Stock.fillna(method='ffill', downcast='infer')
# Out:
# /home/arthur/.pyenv/versions/3.6.1/envs/calcul/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
cars.columns
# Out:
# Index(['ID', 'Type', 'UGS', 'Nom', 'Publié', 'Mis en avant&nbsp;?',
#        'Visibilité dans le catalogue', 'Description courte', 'Description',
#        'Date de début de promo', 'Date de fin de promo', 'État de la TVA',
#        'Classe TVA', 'En Stock&nbsp;?', 'Stock',
#        'Autoriser les commandes de produits en rupture&nbsp;?',
#        'Vendre individuellement&nbsp;?', 'Poids (kg)', 'Longueur (cm)',
#        'Largeur (cm)', 'Hauteur (cm)', 'Activer les avis&nbsp;?',
#        'Note d&rsquo;achat', 'Tarif promo', 'Tarif régulier', 'Catégories',
#        'Étiquettes', 'Classe de livraison', 'Images',
#        'Limite de téléchargement',
#        'Jours d&rsquo;expiration du téléchargement', 'Parent',
#        'Produits groupés', 'Montée en gamme', 'Ventes croisées', 'URL externe',
#        'Bouton texte', 'Méta&nbsp;: _yoast_wpseo_primary_product_cat',
#        'Méta&nbsp;: _yoast_wpseo_content_score', 'Nom de téléchargement 1',
# ...

# %%
cars[]cars.in
# Out:
#        ID                Type  UGS  \
# 44   2670            variable  NaN
# 45   2671  variation, virtual  NaN
# 46   2672  variation, virtual  NaN
# 47   2673  variation, virtual  NaN
# 48   2680            variable  NaN
# 49   2683  variation, virtual  NaN
# 50   2684  variation, virtual  NaN
# 51   2685  variation, virtual  NaN
# 52   2690            variable  NaN
# 53   2692  variation, virtual  NaN
# 54   2693  variation, virtual  NaN
# 55   2694            variable  NaN
# 56   2695  variation, virtual  NaN
# 57   2696  variation, virtual  NaN
# 58   2697  variation, virtual  NaN
# 59   2698            variable  NaN
# 60   2699  variation, virtual  NaN
# 61   2700  variation, virtual  NaN
# 62   2701  variation, virtual  NaN
# 63   2702            variable  NaN
# 64   2704  variation, virtual  NaN
# 65   2705  variation, virtual  NaN
# 66   2706            variable  NaN
# 67   2707  variation, virtual  NaN
# 68   2708  variation, virtual  NaN
# ...
